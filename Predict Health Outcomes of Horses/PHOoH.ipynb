# %% [markdown]
# # Inisiasi Kebutuhan library dan functions

# %%
# Import library

# library kebutuhan
import os
import datetime
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score

# library algoritma
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# Macam macam algoritma

# komen paket yang tidak digunakan
algorithm_pack = [[GaussianNB(), 'Naive Bayes', 'NB'],
                [KNeighborsClassifier(), 'K Nearest Neighbors', 'KNN'],
                [SVC(), 'Support Vector Machine', 'SVM'],
                [GradientBoostingClassifier(random_state=100,), 'Gradient Boosting', 'GB'],
                [DecisionTreeClassifier(random_state=100), 'Decision Tree', 'DT'],
                [RandomForestClassifier(random_state=100), 'Random Forest','RF'],
                [MLPClassifier(max_iter=1000), 'Multi-layer Perceptron', 'MLP']]

# Fungsi untuk menampilkan opsi algoritma apa yang ingin dipakai
def algorithm_option_string():
    string = ''
    for i in range(len(algorithm_pack)):
        string += f"{i}. {algorithm_pack[i][1]}"
    string += '\n['
    for i in range(len(algorithm_pack)):
        if(i == len(algorithm_pack) - 1):
            string+= f"{i}]: "
        else:
            string+= f"{i}/"
    return string

# Fungsi untuk print error dengan warna merah dan diberi jarak
def print_error(string):
    print("\n\033[91m"+string+"\033[0m\n")

# Fungsi untuk validasi input opsi integer
def get_integer_option(min_value, max_value, prompt):
    while True:
        try:
            value = int(input(prompt))
            if min_value <= value <= max_value:
                return value
            else:
                print_error(f"Option must be between {min_value} and {max_value}")
        except ValueError:
            print_error(f"Invalid option. Please enter a valid integer value between {min_value} and {max_value}")

def get_current_time(format=None):
    """Gets the current time in Python and optionally formats it.

    Args:
        format (str, optional): The desired format for the time string.
            Defaults to None, which returns the time in ISO 8601 format (YYYY-MM-DD HH:MM:SS).
            Common format codes include:
                - %Y: Year (e.g., 2024)
                - %m: Month (e.g., 02)
                - %d: Day of the month (e.g., 27)
                - %H: Hour in 24-hour format (e.g., 16)
                - %M: Minute (e.g., 58)
                - %S: Second (e.g., 24)
                - %f: Microseconds (e.g., 406569)

    Returns:
        str: The formatted current time string.
    """

    current_time = datetime.datetime.now()

    if format:
        return current_time.strftime(format)
    else:
        return current_time.isoformat()
    
current_time = get_current_time("%d-%m-%y_%H=%M=%S")
    
def remove_file(filename):
    if os.path.exists(filename):
        os.remove(filename)

# %% [markdown]
# # -- Baca data dan menyimpan data original

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
origin_test_data = test_data

# %% [markdown]
# # Melihat Info dari train data

# %%
train_data.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane  ...  \
# 0                cool          reduced   dark_cyanotic  ...
# 1                cool           normal   pale_cyanotic  ...
# 2                cool          reduced       pale_pink  ...
# 3                cold          reduced       pale_pink  ...
# 4              normal           normal     normal_pink  ...
#
#   packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0               57.0           8.5     serosanguious            3.4
# 1               33.0          64.0     serosanguious            2.0
# 2               37.0           6.4     serosanguious            3.4
# 3               53.0           7.0            cloudy            3.9
# 4               47.0           7.3            cloudy            2.6
#
#   surgical_lesion lesion_1  lesion_2 lesion_3 cp_data     outcome
# 0             yes     2209         0        0      no        died
# 1             yes     2208         0        0      no  euthanized
# 2             yes     5124         0        0      no       lived
# 3             yes     2208         0        0     yes       lived
# 4              no        0         0        0     yes       lived
#
# [5 rows x 29 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1235 non-null   int64
#  1   surgery                1235 non-null   object
#  2   age                    1235 non-null   object
#  3   hospital_number        1235 non-null   int64
#  4   rectal_temp            1235 non-null   float64
#  5   pulse                  1235 non-null   float64
#  6   respiratory_rate       1235 non-null   float64
#  7   temp_of_extremities    1196 non-null   object
#  8   peripheral_pulse       1175 non-null   object
#  9   mucous_membrane        1214 non-null   object
#  10  capillary_refill_time  1229 non-null   object
#  11  pain                   1191 non-null   object
#  12  peristalsis            1215 non-null   object
#  13  abdominal_distention   1212 non-null   object
#  14  nasogastric_tube       1155 non-null   object
#  15  nasogastric_reflux     1214 non-null   object
#  16  nasogastric_reflux_ph  1235 non-null   float64
#  17  rectal_exam_feces      1045 non-null   object
#  18  abdomen                1022 non-null   object
#  19  packed_cell_volume     1235 non-null   float64
#  20  total_protein          1235 non-null   float64
#  21  abdomo_appearance      1187 non-null   object
#  22  abdomo_protein         1235 non-null   float64
#  23  surgical_lesion        1235 non-null   object
#  24  lesion_1               1235 non-null   int64
#  25  lesion_2               1235 non-null   int64
#  26  lesion_3               1235 non-null   int64
#  27  cp_data                1235 non-null   object
#  28  outcome                1235 non-null   object
# dtypes: float64(7), int64(5), object(17)
# memory usage: 279.9+ KB

# %%
train_data.describe()
# Out:
#               id  hospital_number  rectal_temp        pulse  respiratory_rate  \
# count  1235.0000     1.235000e+03  1235.000000  1235.000000       1235.000000
# mean    617.0000     9.545004e+05    38.202186    79.574089         30.054251
# std     356.6581     1.356403e+06     0.788668    29.108638         16.452066
# min       0.0000     5.213990e+05    35.400000    30.000000          8.000000
# 25%     308.5000     5.288000e+05    37.800000    53.000000         18.000000
# 50%     617.0000     5.297770e+05    38.200000    76.000000         28.000000
# 75%     925.5000     5.341450e+05    38.600000   100.000000         36.000000
# max    1234.0000     5.305129e+06    40.800000   184.000000         96.000000
#
#        nasogastric_reflux_ph  packed_cell_volume  total_protein  \
# count            1235.000000         1235.000000    1235.000000
# mean                4.382591           49.602429      21.388016
# std                 1.937357           10.535800      26.676453
# min                 1.000000           23.000000       3.500000
# 25%                 2.000000           43.000000       6.600000
# 50%                 4.500000           48.000000       7.500000
# 75%                 6.000000           57.000000       9.100000
# max                 7.500000           75.000000      89.000000
#
#        abdomo_protein      lesion_1     lesion_2     lesion_3
# count     1235.000000   1235.000000  1235.000000  1235.000000
# mean         3.290931   3832.496356    14.612146     3.577328
# std          1.589195   5436.733774   193.705735    88.858953
# min          0.100000      0.000000     0.000000     0.000000
# 25%          2.000000   2205.000000     0.000000     0.000000
# 50%          3.000000   2209.000000     0.000000     0.000000
# 75%          4.300000   3205.000000     0.000000     0.000000
# max         10.100000  41110.000000  3112.000000  2209.000000

# %% [markdown]
# # -- Drop kolom yang tidak relevan dan set kolom yang ingin diprediksi

# %%
# Ganti isi dengan fitur yang sesuai dengan data
dropped_columns = ['id', 'hospital_number', 'lesion_2', 'lesion_3']
target_column = 'outcome'

categorical_features = train_data.drop(columns=dropped_columns + [target_column]).select_dtypes(include=['object']).columns.tolist()
numerical_features = train_data.drop(columns=dropped_columns + [target_column]).select_dtypes(exclude=['object']).columns.tolist()

train_data = train_data.drop(columns=dropped_columns)
test_data = test_data.drop(columns=dropped_columns)

# %% [markdown]
# # Melihat kembali apakah fitur kategorikal dan fitur numerikal sudah benar

# %%
print(categorical_features)
print(numerical_features)
# Out:
# ['surgery', 'age', 'temp_of_extremities', 'peripheral_pulse', 'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis', 'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux', 'rectal_exam_feces', 'abdomen', 'abdomo_appearance', 'surgical_lesion', 'cp_data']
# ['rectal_temp', 'pulse', 'respiratory_rate', 'nasogastric_reflux_ph', 'packed_cell_volume', 'total_protein', 'abdomo_protein', 'lesion_1']

# %% [markdown]
# # Melakukan Preprocessing sesuai kebutuhan pada data sebelum di latih

# %%
def null_to_none(s):
    if isinstance(s, str):
        return s
    else:
        return "none"

# %%
for categories in categorical_features:
    train_data[categories] =train_data[categories].apply(null_to_none)
    test_data[categories] =test_data[categories].apply(null_to_none)

# %%
train_data.T
# Out:
#                                 0              1              2     \
# surgery                          yes            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.1           37.5           38.3
# pulse                          132.0           88.0          120.0
# respiratory_rate                24.0           12.0           28.0
# temp_of_extremities             cool           cool           cool
# peripheral_pulse             reduced         normal        reduced
# mucous_membrane        dark_cyanotic  pale_cyanotic      pale_pink
# capillary_refill_time     more_3_sec     more_3_sec     less_3_sec
# pain                       depressed      mild_pain   extreme_pain
# peristalsis                   absent         absent     hypomotile
# abdominal_distention          slight       moderate       moderate
# nasogastric_tube              slight           none         slight
# nasogastric_reflux      less_1_liter   more_1_liter           none
# nasogastric_reflux_ph            6.5            2.0            3.5
# rectal_exam_feces          decreased         absent           none
# abdomen                distend_small  distend_small  distend_large
# packed_cell_volume              57.0           33.0           37.0
# total_protein                    8.5           64.0            6.4
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   3.4            2.0            3.4
# surgical_lesion                  yes            yes            yes
# lesion_1                        2209           2208           5124
# cp_data                           no             no             no
# outcome                         died     euthanized          lived
#
#                                 3             4             5     \
# surgery                          yes            no            no
# age                            adult         adult         adult
# rectal_temp                     37.1          38.0          38.1
# pulse                           72.0          52.0          56.0
# respiratory_rate                30.0          48.0          32.0
# temp_of_extremities             cold        normal        normal
# peripheral_pulse             reduced        normal        normal
# mucous_membrane            pale_pink   normal_pink   bright_pink
# capillary_refill_time     more_3_sec    less_3_sec    less_3_sec
# pain                       mild_pain         alert     depressed
# peristalsis               hypomotile    hypomotile    hypomotile
# abdominal_distention        moderate          none          none
# nasogastric_tube              slight        slight          none
# nasogastric_reflux      more_1_liter  less_1_liter  more_1_liter
# nasogastric_reflux_ph            2.0           7.0           5.0
# rectal_exam_feces          decreased        normal     decreased
# abdomen                distend_small        normal          firm
# packed_cell_volume              53.0          47.0          49.0
# total_protein                    7.0           7.3           8.0
# abdomo_appearance             cloudy        cloudy        cloudy
# abdomo_protein                   3.9           2.6           2.8
# surgical_lesion                  yes            no            no
# lesion_1                        2208             0             0
# cp_data                          yes           yes           yes
# outcome                        lived         lived         lived
#
#                                6              7             8           9     \
# surgery                         yes             no            no         yes
# age                           adult          adult         adult       adult
# rectal_temp                    38.3           39.2          37.4        38.3
# pulse                          36.0          114.0          48.0       129.0
# respiratory_rate               16.0           24.0          12.0        48.0
# temp_of_extremities            cool           cool          cool        cool
# peripheral_pulse            reduced        reduced       reduced     reduced
# mucous_membrane         normal_pink  pale_cyanotic   normal_pink   pale_pink
# capillary_refill_time    less_3_sec     more_3_sec    less_3_sec  less_3_sec
# pain                    severe_pain      mild_pain         alert   depressed
# peristalsis                  normal     hypomotile   hypermotile      absent
# abdominal_distention         slight       moderate        slight    moderate
# nasogastric_tube               none         slight        slight      slight
# nasogastric_reflux     more_1_liter           none  more_1_liter        none
# nasogastric_reflux_ph           2.0            4.5           7.0         4.4
# rectal_exam_feces         decreased         absent        normal        none
# abdomen                        none  distend_small          firm        none
# packed_cell_volume             43.0           57.0          40.0        57.0
# total_protein                  75.0            7.6           7.8         4.9
# abdomo_appearance            cloudy  serosanguious        cloudy      cloudy
# abdomo_protein                  1.0            4.5           2.6         2.9
# surgical_lesion                  no            yes            no         yes
# lesion_1                       3111           2207             0        3209
# cp_data                         yes            yes           yes         yes
# outcome                  euthanized           died         lived        died
#
#                        ...           1225           1226          1227  \
# surgery                ...            yes            yes           yes
# age                    ...          adult          young         adult
# rectal_temp            ...           39.3           36.1          38.5
# pulse                  ...           54.0           60.0          48.0
# respiratory_rate       ...           51.0           20.0          16.0
# temp_of_extremities    ...           cool           cool        normal
# peripheral_pulse       ...         normal        reduced        normal
# mucous_membrane        ...     bright_red    normal_pink   normal_pink
# capillary_refill_time  ...     less_3_sec     less_3_sec    less_3_sec
# pain                   ...      depressed      mild_pain         alert
# peristalsis            ...     hypomotile     hypomotile    hypomotile
# abdominal_distention   ...           none       moderate        slight
# nasogastric_tube       ...         slight         slight        slight
# nasogastric_reflux     ...           none   less_1_liter  less_1_liter
# nasogastric_reflux_ph  ...            4.0            4.0           1.5
# rectal_exam_feces      ...      decreased      decreased     decreased
# abdomen                ...  distend_small  distend_small          firm
# packed_cell_volume     ...           50.0           47.0          41.0
# total_protein          ...            7.8            7.6          61.0
# abdomo_appearance      ...  serosanguious         cloudy         clear
# abdomo_protein         ...            1.0            3.0           1.0
# surgical_lesion        ...            yes            yes            no
# lesion_1               ...          31110           2124             0
# cp_data                ...             no            yes            no
# outcome                ...          lived          lived         lived
#
#                                 1228           1229           1230  \
# surgery                          yes            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.3           38.0           38.5
# pulse                           48.0          136.0          129.0
# respiratory_rate                20.0           20.0           48.0
# temp_of_extremities           normal           cool           cool
# peripheral_pulse              normal        reduced        reduced
# mucous_membrane          bright_pink     bright_red      pale_pink
# capillary_refill_time     more_3_sec     less_3_sec     more_3_sec
# pain                       depressed      depressed      depressed
# peristalsis                   absent     hypomotile         absent
# abdominal_distention          slight       moderate       moderate
# nasogastric_tube                none         slight           none
# nasogastric_reflux      less_1_liter   more_1_liter   more_1_liter
# nasogastric_reflux_ph            2.0            5.0            2.0
# rectal_exam_feces          decreased      decreased           none
# abdomen                distend_small  distend_small  distend_large
# packed_cell_volume              41.0           66.0           57.0
# total_protein                   65.0           65.0           66.0
# abdomo_appearance              clear  serosanguious  serosanguious
# abdomo_protein                   2.0            2.0            2.0
# surgical_lesion                  yes            yes            yes
# lesion_1                        3111           2208           2206
# cp_data                           no             no             no
# outcome                        lived          lived          lived
#
#                                 1231         1232           1233  \
# surgery                          yes          yes            yes
# age                            adult        young          adult
# rectal_temp                     37.5         37.5           38.1
# pulse                           60.0         84.0           70.0
# respiratory_rate                50.0         40.0           16.0
# temp_of_extremities             cool       normal         normal
# peripheral_pulse             reduced      reduced        reduced
# mucous_membrane        pale_cyanotic  normal_pink     bright_red
# capillary_refill_time     less_3_sec   less_3_sec     less_3_sec
# pain                       mild_pain    mild_pain      mild_pain
# peristalsis               hypomotile   hypomotile     hypomotile
# abdominal_distention          slight       slight         slight
# nasogastric_tube              slight       slight           none
# nasogastric_reflux              none         none   more_1_liter
# nasogastric_reflux_ph            3.0          3.0            2.0
# rectal_exam_feces          decreased    increased         absent
# abdomen                distend_small         firm  distend_small
# packed_cell_volume              35.0         40.0           58.0
# total_protein                    6.4          5.9           74.0
# abdomo_appearance      serosanguious       cloudy         cloudy
# abdomo_protein                   3.6          7.0            2.0
# surgical_lesion                  yes          yes            yes
# lesion_1                        2209          400           2209
# cp_data                          yes          yes             no
# outcome                         died        lived          lived
#
#                                 1234
# surgery                          yes
# age                            adult
# rectal_temp                     38.1
# pulse                           54.0
# respiratory_rate                36.0
# temp_of_extremities           normal
# peripheral_pulse              normal
# mucous_membrane            pale_pink
# capillary_refill_time     less_3_sec
# pain                       mild_pain
# peristalsis                   absent
# abdominal_distention            none
# nasogastric_tube              slight
# nasogastric_reflux              none
# nasogastric_reflux_ph            3.0
# rectal_exam_feces               none
# abdomen                distend_small
# packed_cell_volume              45.0
# total_protein                    6.0
# abdomo_appearance              clear
# abdomo_protein                   3.6
# surgical_lesion                  yes
# lesion_1                        2124
# cp_data                          yes
# outcome                        lived
#
# [25 rows x 1235 columns]

# %%
test_data.T
# Out:
#                                  0              1              2    \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.6           38.2           37.7
# pulse                           40.0          112.0           66.0
# respiratory_rate                20.0           48.0           12.0
# temp_of_extremities           normal           cool           cool
# peripheral_pulse              normal        reduced         normal
# mucous_membrane          normal_pink    bright_pink     bright_red
# capillary_refill_time     less_3_sec     more_3_sec     less_3_sec
# pain                       mild_pain      depressed      mild_pain
# peristalsis               hypomotile     hypomotile     hypomotile
# abdominal_distention          slight       moderate         slight
# nasogastric_tube                none         slight         slight
# nasogastric_reflux              none           none           none
# nasogastric_reflux_ph            7.0            3.5            3.0
# rectal_exam_feces             normal      decreased         normal
# abdomen                distend_small  distend_small  distend_small
# packed_cell_volume              42.0           44.0           31.5
# total_protein                    7.5            6.0            6.0
# abdomo_appearance              clear  serosanguious         cloudy
# abdomo_protein                   2.3            2.6            1.6
# surgical_lesion                   no             no            yes
# lesion_1                           0           2208           2205
# cp_data                           no            yes            yes
#
#                                  3              4              5    \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     37.1           38.3           38.5
# pulse                           88.0           50.0          104.0
# respiratory_rate                20.0           12.0           36.0
# temp_of_extremities             cool           none           cool
# peripheral_pulse             reduced         normal         normal
# mucous_membrane        pale_cyanotic    bright_pink     bright_red
# capillary_refill_time     less_3_sec     less_3_sec     more_3_sec
# pain                       depressed      mild_pain    severe_pain
# peristalsis                   absent         absent         absent
# abdominal_distention          severe         slight         slight
# nasogastric_tube              slight         slight           none
# nasogastric_reflux      more_1_liter           none   more_1_liter
# nasogastric_reflux_ph            2.0            3.0            5.0
# rectal_exam_feces             absent      decreased         normal
# abdomen                distend_large  distend_small  distend_small
# packed_cell_volume              75.0           37.0           69.0
# total_protein                   81.0            6.8            8.9
# abdomo_appearance               none         cloudy  serosanguious
# abdomo_protein                   1.0            2.6            6.0
# surgical_lesion                  yes            yes            yes
# lesion_1                        1400           2208           2207
# cp_data                           no            yes            yes
#
#                                  6              7              8    \
# surgery                          yes             no            yes
# age                            adult          young          adult
# rectal_temp                     40.8           40.3           38.3
# pulse                          114.0          114.0           66.0
# respiratory_rate                36.0           36.0           12.0
# temp_of_extremities             cold           cool           cool
# peripheral_pulse             reduced        reduced        reduced
# mucous_membrane        dark_cyanotic  pale_cyanotic      pale_pink
# capillary_refill_time     more_3_sec     more_3_sec     less_3_sec
# pain                       depressed      depressed      mild_pain
# peristalsis                   absent     hypomotile     hypomotile
# abdominal_distention        moderate       moderate       moderate
# nasogastric_tube              slight           none         slight
# nasogastric_reflux              none           none   less_1_liter
# nasogastric_reflux_ph            3.5            7.0            4.4
# rectal_exam_feces             normal      decreased      decreased
# abdomen                distend_small           none  distend_large
# packed_cell_volume              40.0           48.0           39.0
# total_protein                    8.6            7.0            6.0
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   2.6            2.8            3.4
# surgical_lesion                  yes            yes            yes
# lesion_1                        2209           2209           4205
# cp_data                          yes            yes             no
#
#                                9    ...            814            815  \
# surgery                         no  ...             no            yes
# age                          adult  ...          adult          adult
# rectal_temp                   38.3  ...           38.6           38.1
# pulse                         64.0  ...          130.0           84.0
# respiratory_rate              22.0  ...           60.0           16.0
# temp_of_extremities         normal  ...           cool           cold
# peripheral_pulse            normal  ...        reduced        reduced
# mucous_membrane        bright_pink  ...      pale_pink  dark_cyanotic
# capillary_refill_time   less_3_sec  ...     less_3_sec     less_3_sec
# pain                     depressed  ...      depressed      depressed
# peristalsis            hypermotile  ...     hypomotile         absent
# abdominal_distention          none  ...       moderate           none
# nasogastric_tube            slight  ...         slight           none
# nasogastric_reflux            none  ...   more_1_liter   less_1_liter
# nasogastric_reflux_ph          7.0  ...            4.0            2.0
# rectal_exam_feces             none  ...         absent         normal
# abdomen                       none  ...  distend_small  distend_large
# packed_cell_volume            54.0  ...           55.0           75.0
# total_protein                  6.0  ...            7.3           81.0
# abdomo_appearance            clear  ...  serosanguious          clear
# abdomo_protein                 1.0  ...            4.3            2.0
# surgical_lesion                 no  ...            yes            yes
# lesion_1                         0  ...           7111           2208
# cp_data                         no  ...            yes             no
#
#                                  816            817            818  \
# surgery                          yes            yes             no
# age                            adult          adult          adult
# rectal_temp                     37.7           37.2           39.6
# pulse                           88.0           60.0          128.0
# respiratory_rate                14.0           44.0           51.0
# temp_of_extremities             cold           cold           cool
# peripheral_pulse              absent        reduced        reduced
# mucous_membrane        pale_cyanotic  pale_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec     more_3_sec
# pain                       depressed      depressed      depressed
# peristalsis               hypomotile         absent         absent
# abdominal_distention        moderate       moderate         slight
# nasogastric_tube              slight           none         slight
# nasogastric_reflux      less_1_liter   more_1_liter   more_1_liter
# nasogastric_reflux_ph            4.5            2.0            2.0
# rectal_exam_feces          decreased      decreased         absent
# abdomen                distend_large  distend_large  distend_small
# packed_cell_volume              50.0           65.0           54.0
# total_protein                    7.7            8.2           13.0
# abdomo_appearance      serosanguious         cloudy  serosanguious
# abdomo_protein                   4.6            3.4            4.7
# surgical_lesion                  yes            yes            yes
# lesion_1                        3205           2206           1400
# cp_data                           no             no            yes
#
#                                  819            820            821  \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     40.3           37.2           39.2
# pulse                          114.0          100.0          132.0
# respiratory_rate                36.0           20.0           12.0
# temp_of_extremities             cool           cool           cool
# peripheral_pulse             reduced        reduced        reduced
# mucous_membrane          normal_pink  pale_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec     more_3_sec
# pain                       depressed   extreme_pain      depressed
# peristalsis               hypomotile         absent     hypomotile
# abdominal_distention        moderate       moderate       moderate
# nasogastric_tube                none         slight         slight
# nasogastric_reflux              none   more_1_liter   more_1_liter
# nasogastric_reflux_ph            7.0            2.0            6.5
# rectal_exam_feces             normal         absent      decreased
# abdomen                distend_large  distend_small           none
# packed_cell_volume              57.0           50.0           53.0
# total_protein                    8.1           66.0            7.6
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   4.5            2.0            4.5
# surgical_lesion                  yes            yes            yes
# lesion_1                        3205           2209           2205
# cp_data                          yes             no             no
#
#                                822            823
# surgery                         no            yes
# age                          adult          adult
# rectal_temp                   38.3           38.1
# pulse                         54.0           66.0
# respiratory_rate              66.0           12.0
# temp_of_extremities         normal           cold
# peripheral_pulse            normal         normal
# mucous_membrane        normal_pink    normal_pink
# capillary_refill_time   less_3_sec     less_3_sec
# pain                     mild_pain      mild_pain
# peristalsis             hypomotile     hypomotile
# abdominal_distention          none         slight
# nasogastric_tube            slight         slight
# nasogastric_reflux            none   more_1_liter
# nasogastric_reflux_ph          7.0            2.0
# rectal_exam_feces           normal         absent
# abdomen                       none  distend_small
# packed_cell_volume            49.0           31.5
# total_protein                  8.6            6.2
# abdomo_appearance            clear           none
# abdomo_protein                 5.0            1.6
# surgical_lesion                 no            yes
# lesion_1                      3111           2205
# cp_data                        yes            yes
#
# [24 rows x 824 columns]

# %%
ordinal_categories = ['temp_of_extremities', 'peripheral_pulse', 'capillary_refill_time', 'pain', 'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux', 'rectal_exam_feces', 'abdomen']
non_ordinal_categories = [element for element in categorical_features if element not in ordinal_categories]

# %%
print(non_ordinal_categories)
# Out:
# ['surgery', 'age', 'mucous_membrane', 'peristalsis', 'abdomo_appearance', 'surgical_lesion', 'cp_data']

# %%
for cols in ordinal_categories:
    print(cols + ": ")
    print(train_data[cols].unique())
# Out:
# temp_of_extremities:
# ['cool' 'cold' 'normal' 'warm' 'none']
# peripheral_pulse:
# ['reduced' 'normal' 'none' 'absent' 'increased']
# capillary_refill_time:
# ['more_3_sec' 'less_3_sec' 'none' '3']
# pain:
# ['depressed' 'mild_pain' 'extreme_pain' 'alert' 'severe_pain' 'none'
#  'slight']
# abdominal_distention:
# ['slight' 'moderate' 'none' 'severe']
# nasogastric_tube:
# ['slight' 'none' 'significant']
# nasogastric_reflux:
# ['less_1_liter' 'more_1_liter' 'none' 'slight']
# rectal_exam_feces:
# ['decreased' 'absent' 'none' 'normal' 'increased' 'serosanguious']
# abdomen:
# ['distend_small' 'distend_large' 'normal' 'firm' 'none' 'other']

# %%
ordinal_orders = [
    ['none', 'warm', 'normal', 'cool', 'cold'], # Kolom temp_of_extremities
    ['none', 'absent', 'reduced', 'normal', 'increased'], # Kolom peripheral_pulse
    ['none', 'less_3_sec', '3', 'more_3_sec'], # Kolom capillary_refill_time
    ['none', 'slight', 'mild_pain', 'alert', 'depressed', 'severe_pain', 'extreme_pain'], # Kolom pain
    ['none', 'slight', 'moderate', 'severe'], # Kolom abdominal_distention
    ['none', 'slight', 'significant'], # Kolom nasogastric_tube
    ['none', 'slight', 'less_1_liter', 'more_1_liter'], # Kolom nasogastric_reflux
    ['none', 'absent', 'decreased', 'normal', 'increased', 'serosanguious'], # Kolom rectal_exam_feces
    ['none', 'normal', 'firm', 'distend_small', 'distend_large', 'other'] # Kolom abdomen
]

# %%
# Ini adalah fungsi transformasi yang digunakan untuk fitur kategorikal non ordinal
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse_output=False))
])  # OneHotEncoder mengubah kategorikal menjadi biner (numerikal)

# Ini adalah fungsi transformasi yang digunakan untuk fitur kategorikal ordinal
ordinal_transformer = Pipeline(steps=[
    ('ordinal', OrdinalEncoder(categories=ordinal_orders))
])

# Ini adalah fungsi transformasi yang digunakan untuk fitur numerikal non ordinal
numerical_imputer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),   # Mengisi null value dengan data median
    ('scaler', StandardScaler())                    # Melakukan standarisasi skalar
])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, non_ordinal_categories),
        ('ord', ordinal_transformer, ordinal_categories),
        ('num', numerical_imputer, numerical_features)
    ], remainder='passthrough')

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# %% [markdown]
# # -- Mulai memisah menjadi x_train, y_train, dan x_test (tidak perlu y_test karena yang diminta hasil prediksi bukan akurasi)

# %%
x_train_visualize = train_data
x_train = train_data.drop(columns=[target_column])
y_train = train_data[target_column]
y_test = test_data
x_test = test_data

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size=0.2, random_state=1, shuffle=True)

# %%
x_train.T
# Out:
#                                 0              1              2     \
# surgery                          yes            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.1           37.5           38.3
# pulse                          132.0           88.0          120.0
# respiratory_rate                24.0           12.0           28.0
# temp_of_extremities             cool           cool           cool
# peripheral_pulse             reduced         normal        reduced
# mucous_membrane        dark_cyanotic  pale_cyanotic      pale_pink
# capillary_refill_time     more_3_sec     more_3_sec     less_3_sec
# pain                       depressed      mild_pain   extreme_pain
# peristalsis                   absent         absent     hypomotile
# abdominal_distention          slight       moderate       moderate
# nasogastric_tube              slight           none         slight
# nasogastric_reflux      less_1_liter   more_1_liter           none
# nasogastric_reflux_ph            6.5            2.0            3.5
# rectal_exam_feces          decreased         absent           none
# abdomen                distend_small  distend_small  distend_large
# packed_cell_volume              57.0           33.0           37.0
# total_protein                    8.5           64.0            6.4
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   3.4            2.0            3.4
# surgical_lesion                  yes            yes            yes
# lesion_1                        2209           2208           5124
# cp_data                           no             no             no
#
#                                 3             4             5     \
# surgery                          yes            no            no
# age                            adult         adult         adult
# rectal_temp                     37.1          38.0          38.1
# pulse                           72.0          52.0          56.0
# respiratory_rate                30.0          48.0          32.0
# temp_of_extremities             cold        normal        normal
# peripheral_pulse             reduced        normal        normal
# mucous_membrane            pale_pink   normal_pink   bright_pink
# capillary_refill_time     more_3_sec    less_3_sec    less_3_sec
# pain                       mild_pain         alert     depressed
# peristalsis               hypomotile    hypomotile    hypomotile
# abdominal_distention        moderate          none          none
# nasogastric_tube              slight        slight          none
# nasogastric_reflux      more_1_liter  less_1_liter  more_1_liter
# nasogastric_reflux_ph            2.0           7.0           5.0
# rectal_exam_feces          decreased        normal     decreased
# abdomen                distend_small        normal          firm
# packed_cell_volume              53.0          47.0          49.0
# total_protein                    7.0           7.3           8.0
# abdomo_appearance             cloudy        cloudy        cloudy
# abdomo_protein                   3.9           2.6           2.8
# surgical_lesion                  yes            no            no
# lesion_1                        2208             0             0
# cp_data                          yes           yes           yes
#
#                                6              7             8           9     \
# surgery                         yes             no            no         yes
# age                           adult          adult         adult       adult
# rectal_temp                    38.3           39.2          37.4        38.3
# pulse                          36.0          114.0          48.0       129.0
# respiratory_rate               16.0           24.0          12.0        48.0
# temp_of_extremities            cool           cool          cool        cool
# peripheral_pulse            reduced        reduced       reduced     reduced
# mucous_membrane         normal_pink  pale_cyanotic   normal_pink   pale_pink
# capillary_refill_time    less_3_sec     more_3_sec    less_3_sec  less_3_sec
# pain                    severe_pain      mild_pain         alert   depressed
# peristalsis                  normal     hypomotile   hypermotile      absent
# abdominal_distention         slight       moderate        slight    moderate
# nasogastric_tube               none         slight        slight      slight
# nasogastric_reflux     more_1_liter           none  more_1_liter        none
# nasogastric_reflux_ph           2.0            4.5           7.0         4.4
# rectal_exam_feces         decreased         absent        normal        none
# abdomen                        none  distend_small          firm        none
# packed_cell_volume             43.0           57.0          40.0        57.0
# total_protein                  75.0            7.6           7.8         4.9
# abdomo_appearance            cloudy  serosanguious        cloudy      cloudy
# abdomo_protein                  1.0            4.5           2.6         2.9
# surgical_lesion                  no            yes            no         yes
# lesion_1                       3111           2207             0        3209
# cp_data                         yes            yes           yes         yes
#
#                        ...           1225           1226          1227  \
# surgery                ...            yes            yes           yes
# age                    ...          adult          young         adult
# rectal_temp            ...           39.3           36.1          38.5
# pulse                  ...           54.0           60.0          48.0
# respiratory_rate       ...           51.0           20.0          16.0
# temp_of_extremities    ...           cool           cool        normal
# peripheral_pulse       ...         normal        reduced        normal
# mucous_membrane        ...     bright_red    normal_pink   normal_pink
# capillary_refill_time  ...     less_3_sec     less_3_sec    less_3_sec
# pain                   ...      depressed      mild_pain         alert
# peristalsis            ...     hypomotile     hypomotile    hypomotile
# abdominal_distention   ...           none       moderate        slight
# nasogastric_tube       ...         slight         slight        slight
# nasogastric_reflux     ...           none   less_1_liter  less_1_liter
# nasogastric_reflux_ph  ...            4.0            4.0           1.5
# rectal_exam_feces      ...      decreased      decreased     decreased
# abdomen                ...  distend_small  distend_small          firm
# packed_cell_volume     ...           50.0           47.0          41.0
# total_protein          ...            7.8            7.6          61.0
# abdomo_appearance      ...  serosanguious         cloudy         clear
# abdomo_protein         ...            1.0            3.0           1.0
# surgical_lesion        ...            yes            yes            no
# lesion_1               ...          31110           2124             0
# cp_data                ...             no            yes            no
#
#                                 1228           1229           1230  \
# surgery                          yes            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.3           38.0           38.5
# pulse                           48.0          136.0          129.0
# respiratory_rate                20.0           20.0           48.0
# temp_of_extremities           normal           cool           cool
# peripheral_pulse              normal        reduced        reduced
# mucous_membrane          bright_pink     bright_red      pale_pink
# capillary_refill_time     more_3_sec     less_3_sec     more_3_sec
# pain                       depressed      depressed      depressed
# peristalsis                   absent     hypomotile         absent
# abdominal_distention          slight       moderate       moderate
# nasogastric_tube                none         slight           none
# nasogastric_reflux      less_1_liter   more_1_liter   more_1_liter
# nasogastric_reflux_ph            2.0            5.0            2.0
# rectal_exam_feces          decreased      decreased           none
# abdomen                distend_small  distend_small  distend_large
# packed_cell_volume              41.0           66.0           57.0
# total_protein                   65.0           65.0           66.0
# abdomo_appearance              clear  serosanguious  serosanguious
# abdomo_protein                   2.0            2.0            2.0
# surgical_lesion                  yes            yes            yes
# lesion_1                        3111           2208           2206
# cp_data                           no             no             no
#
#                                 1231         1232           1233  \
# surgery                          yes          yes            yes
# age                            adult        young          adult
# rectal_temp                     37.5         37.5           38.1
# pulse                           60.0         84.0           70.0
# respiratory_rate                50.0         40.0           16.0
# temp_of_extremities             cool       normal         normal
# peripheral_pulse             reduced      reduced        reduced
# mucous_membrane        pale_cyanotic  normal_pink     bright_red
# capillary_refill_time     less_3_sec   less_3_sec     less_3_sec
# pain                       mild_pain    mild_pain      mild_pain
# peristalsis               hypomotile   hypomotile     hypomotile
# abdominal_distention          slight       slight         slight
# nasogastric_tube              slight       slight           none
# nasogastric_reflux              none         none   more_1_liter
# nasogastric_reflux_ph            3.0          3.0            2.0
# rectal_exam_feces          decreased    increased         absent
# abdomen                distend_small         firm  distend_small
# packed_cell_volume              35.0         40.0           58.0
# total_protein                    6.4          5.9           74.0
# abdomo_appearance      serosanguious       cloudy         cloudy
# abdomo_protein                   3.6          7.0            2.0
# surgical_lesion                  yes          yes            yes
# lesion_1                        2209          400           2209
# cp_data                          yes          yes             no
#
#                                 1234
# surgery                          yes
# age                            adult
# rectal_temp                     38.1
# pulse                           54.0
# respiratory_rate                36.0
# temp_of_extremities           normal
# peripheral_pulse              normal
# mucous_membrane            pale_pink
# capillary_refill_time     less_3_sec
# pain                       mild_pain
# peristalsis                   absent
# abdominal_distention            none
# nasogastric_tube              slight
# nasogastric_reflux              none
# nasogastric_reflux_ph            3.0
# rectal_exam_feces               none
# abdomen                distend_small
# packed_cell_volume              45.0
# total_protein                    6.0
# abdomo_appearance              clear
# abdomo_protein                   3.6
# surgical_lesion                  yes
# lesion_1                        2124
# cp_data                          yes
#
# [24 rows x 1235 columns]

# %%
x_test.T
# Out:
#                                  0              1              2    \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     38.6           38.2           37.7
# pulse                           40.0          112.0           66.0
# respiratory_rate                20.0           48.0           12.0
# temp_of_extremities           normal           cool           cool
# peripheral_pulse              normal        reduced         normal
# mucous_membrane          normal_pink    bright_pink     bright_red
# capillary_refill_time     less_3_sec     more_3_sec     less_3_sec
# pain                       mild_pain      depressed      mild_pain
# peristalsis               hypomotile     hypomotile     hypomotile
# abdominal_distention          slight       moderate         slight
# nasogastric_tube                none         slight         slight
# nasogastric_reflux              none           none           none
# nasogastric_reflux_ph            7.0            3.5            3.0
# rectal_exam_feces             normal      decreased         normal
# abdomen                distend_small  distend_small  distend_small
# packed_cell_volume              42.0           44.0           31.5
# total_protein                    7.5            6.0            6.0
# abdomo_appearance              clear  serosanguious         cloudy
# abdomo_protein                   2.3            2.6            1.6
# surgical_lesion                   no             no            yes
# lesion_1                           0           2208           2205
# cp_data                           no            yes            yes
#
#                                  3              4              5    \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     37.1           38.3           38.5
# pulse                           88.0           50.0          104.0
# respiratory_rate                20.0           12.0           36.0
# temp_of_extremities             cool           none           cool
# peripheral_pulse             reduced         normal         normal
# mucous_membrane        pale_cyanotic    bright_pink     bright_red
# capillary_refill_time     less_3_sec     less_3_sec     more_3_sec
# pain                       depressed      mild_pain    severe_pain
# peristalsis                   absent         absent         absent
# abdominal_distention          severe         slight         slight
# nasogastric_tube              slight         slight           none
# nasogastric_reflux      more_1_liter           none   more_1_liter
# nasogastric_reflux_ph            2.0            3.0            5.0
# rectal_exam_feces             absent      decreased         normal
# abdomen                distend_large  distend_small  distend_small
# packed_cell_volume              75.0           37.0           69.0
# total_protein                   81.0            6.8            8.9
# abdomo_appearance               none         cloudy  serosanguious
# abdomo_protein                   1.0            2.6            6.0
# surgical_lesion                  yes            yes            yes
# lesion_1                        1400           2208           2207
# cp_data                           no            yes            yes
#
#                                  6              7              8    \
# surgery                          yes             no            yes
# age                            adult          young          adult
# rectal_temp                     40.8           40.3           38.3
# pulse                          114.0          114.0           66.0
# respiratory_rate                36.0           36.0           12.0
# temp_of_extremities             cold           cool           cool
# peripheral_pulse             reduced        reduced        reduced
# mucous_membrane        dark_cyanotic  pale_cyanotic      pale_pink
# capillary_refill_time     more_3_sec     more_3_sec     less_3_sec
# pain                       depressed      depressed      mild_pain
# peristalsis                   absent     hypomotile     hypomotile
# abdominal_distention        moderate       moderate       moderate
# nasogastric_tube              slight           none         slight
# nasogastric_reflux              none           none   less_1_liter
# nasogastric_reflux_ph            3.5            7.0            4.4
# rectal_exam_feces             normal      decreased      decreased
# abdomen                distend_small           none  distend_large
# packed_cell_volume              40.0           48.0           39.0
# total_protein                    8.6            7.0            6.0
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   2.6            2.8            3.4
# surgical_lesion                  yes            yes            yes
# lesion_1                        2209           2209           4205
# cp_data                          yes            yes             no
#
#                                9    ...            814            815  \
# surgery                         no  ...             no            yes
# age                          adult  ...          adult          adult
# rectal_temp                   38.3  ...           38.6           38.1
# pulse                         64.0  ...          130.0           84.0
# respiratory_rate              22.0  ...           60.0           16.0
# temp_of_extremities         normal  ...           cool           cold
# peripheral_pulse            normal  ...        reduced        reduced
# mucous_membrane        bright_pink  ...      pale_pink  dark_cyanotic
# capillary_refill_time   less_3_sec  ...     less_3_sec     less_3_sec
# pain                     depressed  ...      depressed      depressed
# peristalsis            hypermotile  ...     hypomotile         absent
# abdominal_distention          none  ...       moderate           none
# nasogastric_tube            slight  ...         slight           none
# nasogastric_reflux            none  ...   more_1_liter   less_1_liter
# nasogastric_reflux_ph          7.0  ...            4.0            2.0
# rectal_exam_feces             none  ...         absent         normal
# abdomen                       none  ...  distend_small  distend_large
# packed_cell_volume            54.0  ...           55.0           75.0
# total_protein                  6.0  ...            7.3           81.0
# abdomo_appearance            clear  ...  serosanguious          clear
# abdomo_protein                 1.0  ...            4.3            2.0
# surgical_lesion                 no  ...            yes            yes
# lesion_1                         0  ...           7111           2208
# cp_data                         no  ...            yes             no
#
#                                  816            817            818  \
# surgery                          yes            yes             no
# age                            adult          adult          adult
# rectal_temp                     37.7           37.2           39.6
# pulse                           88.0           60.0          128.0
# respiratory_rate                14.0           44.0           51.0
# temp_of_extremities             cold           cold           cool
# peripheral_pulse              absent        reduced        reduced
# mucous_membrane        pale_cyanotic  pale_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec     more_3_sec
# pain                       depressed      depressed      depressed
# peristalsis               hypomotile         absent         absent
# abdominal_distention        moderate       moderate         slight
# nasogastric_tube              slight           none         slight
# nasogastric_reflux      less_1_liter   more_1_liter   more_1_liter
# nasogastric_reflux_ph            4.5            2.0            2.0
# rectal_exam_feces          decreased      decreased         absent
# abdomen                distend_large  distend_large  distend_small
# packed_cell_volume              50.0           65.0           54.0
# total_protein                    7.7            8.2           13.0
# abdomo_appearance      serosanguious         cloudy  serosanguious
# abdomo_protein                   4.6            3.4            4.7
# surgical_lesion                  yes            yes            yes
# lesion_1                        3205           2206           1400
# cp_data                           no             no            yes
#
#                                  819            820            821  \
# surgery                           no            yes            yes
# age                            adult          adult          adult
# rectal_temp                     40.3           37.2           39.2
# pulse                          114.0          100.0          132.0
# respiratory_rate                36.0           20.0           12.0
# temp_of_extremities             cool           cool           cool
# peripheral_pulse             reduced        reduced        reduced
# mucous_membrane          normal_pink  pale_cyanotic  dark_cyanotic
# capillary_refill_time     more_3_sec     more_3_sec     more_3_sec
# pain                       depressed   extreme_pain      depressed
# peristalsis               hypomotile         absent     hypomotile
# abdominal_distention        moderate       moderate       moderate
# nasogastric_tube                none         slight         slight
# nasogastric_reflux              none   more_1_liter   more_1_liter
# nasogastric_reflux_ph            7.0            2.0            6.5
# rectal_exam_feces             normal         absent      decreased
# abdomen                distend_large  distend_small           none
# packed_cell_volume              57.0           50.0           53.0
# total_protein                    8.1           66.0            7.6
# abdomo_appearance      serosanguious  serosanguious  serosanguious
# abdomo_protein                   4.5            2.0            4.5
# surgical_lesion                  yes            yes            yes
# lesion_1                        3205           2209           2205
# cp_data                          yes             no             no
#
#                                822            823
# surgery                         no            yes
# age                          adult          adult
# rectal_temp                   38.3           38.1
# pulse                         54.0           66.0
# respiratory_rate              66.0           12.0
# temp_of_extremities         normal           cold
# peripheral_pulse            normal         normal
# mucous_membrane        normal_pink    normal_pink
# capillary_refill_time   less_3_sec     less_3_sec
# pain                     mild_pain      mild_pain
# peristalsis             hypomotile     hypomotile
# abdominal_distention          none         slight
# nasogastric_tube            slight         slight
# nasogastric_reflux            none   more_1_liter
# nasogastric_reflux_ph          7.0            2.0
# rectal_exam_feces           normal         absent
# abdomen                       none  distend_small
# packed_cell_volume            49.0           31.5
# total_protein                  8.6            6.2
# abdomo_appearance            clear           none
# abdomo_protein                 5.0            1.6
# surgical_lesion                 no            yes
# lesion_1                      3111           2205
# cp_data                        yes            yes
#
# [24 rows x 824 columns]

# %%
x_train_visualize = pipeline.fit_transform(x_train_visualize)
x_train = pipeline.fit_transform(x_train)
x_test = pipeline.transform(x_test)
y_test = pipeline.transform(y_test)

all_column_names = preprocessor.get_feature_names_out()
all_column_names = [name[name.find("__") + 2:] for name in all_column_names]

# %%
predictions = algorithm_pack[0][0].predict(x_test) #NB
predictions = algorithm_pack[1][0].predict(x_test) #KNN
predictions = algorithm_pack[4][0].predict(x_test) #GB
predictions = algorithm_pack[5][0].predict(x_test) #DT

# %%
algorithm_pack[0][0].fit(X_train, y_train)
predictions = algorithm_pack[0][0].predict(x_test) #NB
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25460\378837831.py in ?()
# ----> 1 algorithm_pack[0][0].fit(X_train, y_train)
#       2 predictions = algorithm_pack[0][0].predict(x_test) #NB
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, sample_weight)
#     259         self : object
#     260             Returns the instance itself.
#     261         """
#     262         y = self._validate_data(y=y)
# --> 263         return self._partial_fit(
#     264             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     265         )
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\naive_bayes.py in ?(self, X, y, classes, _refit, sample_weight)
#     419         if _refit:
#     420             self.classes_ = None
#     421
#     422         first_call = _check_partial_fit_first_call(self, classes)
# --> 423         X, y = self._validate_data(X, y, reset=first_call)
#     424         if sample_weight is not None:
#     425             sample_weight = _check_sample_weight(sample_weight, X)
#     426
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'no'

# %%
# algorithm_pack_2 = [[GaussianNB(), 'Naive Bayes', 'NB'],
#                 [KNeighborsClassifier(), 'K Nearest Neighbors', 'KNN'],
#                 # [SVC(), 'Support Vector Machine', 'SVM'], 
#                 [GradientBoostingClassifier(random_state=100, learning_rate=0.15), 'Gradient Boosting', 'GB'],
#                 [DecisionTreeClassifier(random_state=100), 'Decision Tree', 'DT']]

# results=[]
# for i in range (len(algorithm_pack_2)):
#     kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#     cv_results = cross_val_score(algorithm_pack_2[i][0], x_train, y_train, cv=kfold, scoring='accuracy')
#     results.append(cv_results)
#     print('%s: %f (%f)' % (algorithm_pack_2[i][2], cv_results.mean(), cv_results.std()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 10
#       8 for i in range (len(algorithm_pack_2)):
#       9     kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
# ---> 10     cv_results = cross_val_score(algorithm_pack_2[i][0], x_train, y_train, cv=kfold, scoring='accuracy')
#      11     results.append(cv_results)
#      12     print('%s: %f (%f)' % (algorithm_pack_2[i][2], cv_results.mean(), cv_results.std()))
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:719, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     716 # To ensure multimetric format is not supported
#     717 scorer = check_scoring(estimator, scoring=scoring)
# --> 719 cv_results = cross_validate(
#     720     estimator=estimator,
#     721     X=X,
#     722     y=y,
#     723     groups=groups,
#     724     scoring={"score": scorer},
#     725     cv=cv,
#     726     n_jobs=n_jobs,
#     727     verbose=verbose,
#     728     fit_params=fit_params,
#     729     params=params,
#     730     pre_dispatch=pre_dispatch,
#     731     error_score=error_score,
#     732 )
#     733 return cv_results["test_score"]
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:351, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     140 """Evaluate metric(s) by cross-validation and also record fit/score times.
#     141
#     142 Read more in the :ref:`User Guide <multimetric_cross_validation>`.
#    (...)
#     347 [0.28009951 0.3908844  0.22784907]
#     348 """
#     349 params = _check_params_groups_deprecation(fit_params, params, groups)
# --> 351 X, y = indexable(X, y)
#     353 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#     355 if callable(scoring):
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:514, in indexable(*iterables)
#     484 """Make arrays indexable for cross-validation.
#     485
#     486 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     510 [[1, 2, 3], array([2, 3, 4]), None, <3x1 sparse matrix ...>]
#     511 """
#     513 result = [_make_indexable(X) for X in iterables]
# --> 514 check_consistent_length(*result)
#     515 return result
#
# File c:\Users\dymik\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1235, 988]

# %%
algorithm_pack_2 = [[GaussianNB(), 'Naive Bayes', 'NB'],
                [KNeighborsClassifier(), 'K Nearest Neighbors', 'KNN'],
                # [SVC(), 'Support Vector Machine', 'SVM'], 
                [GradientBoostingClassifier(random_state=100, learning_rate=0.15), 'Gradient Boosting', 'GB'],
                [DecisionTreeClassifier(random_state=100), 'Decision Tree', 'DT']]
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import StratifiedKFold
# from sklearn.metrics import classification_report
# import numpy as np

# algorithm_pack_2 = [[GaussianNB(), 'Naive Bayes', 'NB'],
#                 [KNeighborsClassifier(), 'K Nearest Neighbors', 'KNN'],
#                 # [SVC(), 'Support Vector Machine', 'SVM'], 
#                 [GradientBoostingClassifier(random_state=100, learning_rate=0.15), 'Gradient Boosting', 'GB'],
#                 [DecisionTreeClassifier(random_state=100), 'Decision Tree', 'DT']]



# results = []

# for i in range(len(algorithm_pack_2)):
#     kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#     cv_results = cross_val_score(algorithm_pack_2[i][0], X_train, y_train, cv=kfold, scoring='accuracy')
#     results.append(cv_results)
#     print('%s: %f (%f)' % (algorithm_pack_2[i][2], cv_results.mean(), cv_results.std()))

# best_model_index = np.argmax(np.mean(results, axis=1))
# best_model_name = algorithm_pack_2[best_model_index][2]
# best_model = algorithm_pack_2[best_model_index][0]
# best_model.fit(X_train, y_train)
# predictions = best_model.predict(X_validation)
# print(f"\nClassification report for the best model which is {best_model_name}:")
# print(classification_report(y_validation, predictions))
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# results=[]
# for i in range (len(algorithm_pack_2)):
#     kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#     cv_results = cross_val_score(algorithm_pack_2[i][0], x_train, y_train, cv=kfold, scoring='accuracy')
#     results.append(cv_results)
#     print('%s: %f (%f)' % (algorithm_pack_2[i][2], cv_results.mean(), cv_results.std()))
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(y_test)
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # algorithm_pack_2[1][0].fit(x_train, y_train)
# # predictions = algorithm_pack_2[1][0].predict(x_test)
# # r2_score(y_test, predictions, force_finite=False)
# for i in range (len(algorithm_pack_2)):
#     algorithm_pack_2[i][0].fit(x_train, y_train)  
#     predictions = algorithm_pack_2[i][0].predict(x_test)
#     print(classification_report(y_test, predictions))
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# algorithm_pack[2][0].fit(x_train, y_train)
# predictions = algorithm_pack[2][0].predict(x_test).round()
# print(classification_report(y_test, predictions))
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # -- Fungsi untuk output csv, diganti berdasarkan kebutuhan

# %% [markdown]
# ## Fungsi untuk prediksi bersifat non probabilitas

# %%
# def output_one_csv(i):
#     # Algoritma untuk output prediksi kedalam csv
#     algorithm_pack[i][0].fit(x_train, y_train)
#     predictions = algorithm_pack[i][0].predict(x_test)
#     ids = origin_test_data['id']
#     output_df = pd.DataFrame({'id': ids, 'outcome': predictions})
#     output_csv_name = f"predictions_{algorithm_pack[i][2]}_{current_time}.csv"
#     output_df.to_csv(output_csv_name, index=False)
    
#     # Algoritma untuk output data yang dipakai untuk melatih model
#     clean_data_df = pd.DataFrame(x_train)
#     clean_data_df.columns = all_column_names
#     clean_data_csv_name = f"clean_data_{algorithm_pack[i][2]}_{current_time}.csv"
#     clean_data_df.to_csv(clean_data_csv_name, index=False)

#     # Algoritma untuk output dokumentasi seperti permasalahan yang diselesaikan, waktu run code, dll.
#     documentation_txt_name = f"documentation_{algorithm_pack[i][2]}_{current_time}.txt"
#     current_ipynb_file = "PHOoH.ipynb"
#     string_to_write = ""
#     with open(documentation_txt_name, "w") as f:
#         # Write your documentation content to the file
#         string_to_write += f"Problem to solve\t\t: {os.path.basename(os.getcwd())}\n"
#         string_to_write += f"Date and Time file created\t: {get_current_time()}\n"
#         string_to_write += f"Algorithm title\t\t\t: {algorithm_pack[i][1]}\n\n"
#         string_to_write += f"Training data info:\n{train_data.dtypes}\n\n"
#         string_to_write += f"Test data info:\n{test_data.dtypes}\n\n"
#         string_to_write += f"Categorical Features\t: {categorical_features}\n"
#         string_to_write += f"Numerical Features\t: {numerical_features}\n\n"
#         string_to_write += f"For more data details see {clean_data_csv_name} (data that are beeing trained)\n"
#         string_to_write += f"For data preprocessing details see {current_ipynb_file} or self\n"
#         f.write(string_to_write)

#     with zipfile.ZipFile(f"complete_data_{algorithm_pack[i][2]}_{current_time}.zip", "w") as zip_file:
#         # Add the current code into the zip
#         zip_file.write(current_ipynb_file, arcname=current_ipynb_file)
#         # Add the CSV file
#         zip_file.write(output_csv_name, arcname=output_csv_name)  # Specify archive name for the CSV
#         zip_file.write(clean_data_csv_name, arcname=clean_data_csv_name)  # Specify archive name for the CSV
#         # Add the text file
#         zip_file.write(documentation_txt_name, arcname=documentation_txt_name)  # Specify archive name for the text file
#         remove_file(clean_data_csv_name)
#         remove_file(documentation_txt_name)
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # -- Fungsi untuk output semua model yang dipakai

# %%
# def output_all_csv():
#     for i in range(len(algorithm_pack)):
#         output_one_csv(i)

# def output_mandatory_csv():
#      for i in range(3):
#         output_one_csv(i)
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # -- Memudahkan untuk outputnya

# %%
# choose = get_integer_option(0, 2, "What do you want to do with the csv?\n0. Train the csv data\n1. Get the info of the csv data\n2. Get the csv of clean preprocessed data\n[0/1/2]: ")

# if(choose == 0):
#     choose = get_integer_option(0, 2, "Use all model?\n0. No\n1. Yes\n2. Mandatory\n[0/1/2]: ")
#     if(choose == 0):
#         choose = get_integer_option(0, len(algorithm_pack) - 1, f"Which model to use?"+algorithm_option_string())
#         output_one_csv(choose)
#     elif(choose == 1):
#         output_all_csv()
#     elif(choose == 2):
#         output_mandatory_csv()
# elif(choose == 1):
#     print("Training data info:\n",train_data.dtypes,"\n")
#     print("Test data info:\n",test_data.dtypes)
#     print("Categorical Features: ",categorical_features)
#     print("Numerical Features: ",numerical_features)
# elif(choose == 2):
#     clean_data_df = pd.DataFrame(x_train)
#     clean_data_df.columns = all_column_names
#     clean_data_df.to_csv('clean_data.csv', index=False)
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Run All
# Out:
# Failed to start the Kernel.
#
# zmq.error.ZMQError: Address in use (addr='tcp://127.0.0.1:9002').
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
